# %%
#1
Categorical variables: represent types of data which
may be divided into groups and can
only take on a limited number of possible values. 
For example, if a dataset is about information related to users, 
then you will typically find
features like country, gender, age group, etc...

ordinal:invloves some order and the values are related to each other
in some way, for example a movie review can have 'Good','Bad','Poor'

nominal: assigns names to clumns without any specific order.
a certain name is not greater than another

Continues features:
Continuous variables are numeric variables that have
an infinite number of values between any two values.
A continuous variable can be numeric or date/time. For example, 
the length of a part or the date and time a payment is received.

scaling:
Min-Max Normalization - Scales all the data between [0, 1] as a default but you can pick
any 2 numbers to scale between.

Standarization - Standard scaling subtracts the mean and divides by the standard deviation.
This centers the feature on zero with unit variance.

Transformation:
If we have skewed data, and we want the data to be in a more normal distribution
(which can be useful for some models)
we can use data transformations. The most common one is log transformations.

Binning:
we can bine a numerical column of a database into a range of two numbers.
for example, we can take an age of 14 and bine it into a range of 10 to 20.

# %%
#2
import pandas as pd
import matplotlib.pyplot as plt
titanic_df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
plt.figure(figsize= (10,5))
titanic_df.Fare.plot(kind="hist", color = 'g')
#Fare distribution
plt.xlabel('Fare')
plt.show()

# %%
first_c = titanic_df[titanic_df.Pclass == 1].Survived.value_counts(normalize=True)
second_c = titanic_df[titanic_df.Pclass == 2].Survived.value_counts(normalize=True)
third_c = titanic_df[titanic_df.Pclass == 3].Survived.value_counts(normalize=True)


fig, ax = plt.subplots(1,3, figsize = (13,6))

ax[0].pie(first_c, labels = first_c.index.map({0: "Not Survived", 1: "Survived"}), autopct = '%1.1f%%',)
ax[0].set_title('First_class')
ax[1].pie(second_c, labels = second_c.index.map({0: "Not Survived", 1: "Survived"}), autopct = '%1.1f%%',)
ax[1].set_title('Second_class')

ax[2].pie(third_c, labels = third_c.index.map({0: "Not Survived", 1: "Survived"}), autopct = '%1.1f%%',)
ax[2].set_title('Third_class')

plt.show()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# age distribution
titanic_df.Age.plot(kind='hist')
plt.xlabel('Age')
plt.title('Age distribution')
plt.show()

# %%
# age ditribution of survived
titanic_df.groupby('Survived')['Age'].plot(kind='kde')
plt.legend()
plt.title('Age by density by survived')
plt.show()

# %%
# survived by gender
male_data = titanic_df[titanic_df.Sex == 'male'].Survived.value_counts(normalize=True)
female_data = titanic_df[titanic_df.Sex == 'female'].Survived.value_counts(normalize=True)
fig, ax = plt.subplots(1,2,figsize=(13,6))
ax[0].pie(male_data, labels = male_data.index.map({0: "Did Not Survive", 1: "Survived"}), autopct = '%1.1f%%',)
ax[0].set_title('Male Passengers')
ax[1].pie(female_data, labels = female_data.index.map({0: "Did Not Survive", 1: "Survived"}), autopct = '%1.1f%%',)
ax[1].set_title('Female Passengers')
# Out:
# Text(0.5, 1.0, 'Female Passengers')

# %%
# survived by class num
first_class = titanic_df[titanic_df.Pclass == 1].Survived.value_counts(normalize=True)
second_class = titanic_df[titanic_df.Pclass == 2].Survived.value_counts(normalize=True)
third_class = titanic_df[titanic_df.Pclass == 3].Survived.value_counts(normalize=True)
fig, ax = plt.subplots(1,3,figsize=(13,6))

ax[0].pie(first_class, labels = first_class.index.map({0: "Did Not Survive", 1: "Survived"}), autopct = '%1.1f%%',)
ax[0].set_title('First Class')

ax[1].pie(second_class, labels = second_class.index.map({0: "Did Not Survive", 1: "Survived"}), autopct = '%1.1f%%',)
ax[1].set_title('Second Class')

ax[2].pie(third_class, labels = third_class.index.map({0: "Did Not Survive", 1: "Survived"}), autopct = '%1.1f%%',)
ax[2].set_title('Third Class')
# Out:
# Text(0.5, 1.0, 'Third Class')

# %%
# survived by siblings on board, parents on board, fare
continuous_features = ['SibSp', 'Parch', 'Fare']
target = 'Survived'
fig, ax = plt.subplots(3,1,figsize=(8, 8))
for i, cont_v in enumerate(continuous_features):
    titanic_df.groupby(target)[cont_v].plot(kind='kde', ax=ax[i])
    ax[i].set_xlabel(cont_v)
    ax[i].legend()

fig.tight_layout()
plt.show()

# %%
#3
titanic_df['Age'].fillna(value = titanic_df.Age.mean(), inplace = True)
titanic_df.Cabin.fillna(value='Unknown', inplace = True)
pd.get_dummies(titanic_df, columns=['Sex'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000      1
# 2                               Heikkinen, Miss. Laina  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000      1
# 4                             Allen, Mr. William Henry  35.000000      0
# ..                                                 ...        ...    ...
# ...

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
df_scaled = titanic_df.copy()
col_names = ['Age','Fare']
features = df_scaled[col_names]
scaler = MinMaxScaler()
df_scaled[col_names] = scaler.fit_transform(features.values)
df_scaled
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male  0.271174
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.472229
# 2                               Heikkinen, Miss. Laina  female  0.321438
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.434531
# 4                             Allen, Mr. William Henry    male  0.434531
# ..                                                 ...     ...       ...
# ...

# %%
from sklearn.preprocessing import FunctionTransformer
import numpy as np
fig,ax=plt.subplots(1,2,figsize=(13, 5))
titanic_df['Age'].plot(kind = 'kde', ax=ax[0]);
ax[0].set_title('Age before Log Transform')
transformer = FunctionTransformer(np.log1p, validate=True)
pd.DataFrame(transformer.transform(titanic_df[['Age']])).plot(kind = 'kde', ax=ax[1]);
ax[1].set_title('Age after Log Transform')
plt.show()

# %%
titanic_df.boxplot(by ='Embarked', column =['Fare'])
# Out:
# <AxesSubplot:title={'center':'Fare'}, xlabel='Embarked'>

# %%
max_fare = titanic_df[titanic_df['Fare'] == titanic_df['Fare'].max()].index
titanic_df.drop(max_fare)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.boxplot(by ='Embarked', column =['SibSp'])
max_sib = titanic_df[titanic_df['SibSp'] == titanic_df['SibSp'].max()].index
titanic_df.drop(max_sib)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic_df.drop(columns = ['Name', 'Ticket'])
# I removed the Name and ticket columns because I don't see any use or comparison that can be made with the column data
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.000000      1      0   7.2500
# 1              2         1       1  female  38.000000      1      0  71.2833
# 2              3         1       3  female  26.000000      0      0   7.9250
# 3              4         1       1  female  35.000000      1      0  53.1000
# 4              5         0       3    male  35.000000      0      0   8.0500
# ..           ...       ...     ...     ...        ...    ...    ...      ...
# 886          887         0       2    male  27.000000      0      0  13.0000
# 887          888         1       1  female  19.000000      0      0  30.0000
# 888          889         0       3  female  29.699118      1      2  23.4500
# 889          890         1       1    male  26.000000      0      0  30.0000
# 890          891         0       3    male  32.000000      0      0   7.7500
#
#        Cabin Embarked
# ...

# %%
#4
import numpy as np
from sklearn.model_selection import train_test_split
import random
X, y = titanic_df[:], range(891)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=random.randint(0,891))
X_test
# Out:
#      PassengerId  Survived  Pclass  \
# 873          874         0       3
# 843          844         0       3
# 849          850         1       1
# 559          560         1       3
# 861          862         0       2
# ..           ...       ...     ...
# 347          348         1       3
# 152          153         0       3
# 326          327         0       3
# 323          324         1       2
# 780          781         1       3
#
#                                                   Name     Sex        Age  \
# 873                        Vander Cruyssen, Mr. Victor    male  47.000000
# 843                         Lemberopolous, Mr. Peter L    male  34.500000
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female  29.699118
# 559       de Messemaeker, Mrs. Guillaume Joseph (Emma)  female  36.000000
# 861                        Giles, Mr. Frederick Edward    male  21.000000
# ..                                                 ...     ...        ...
# ...

# %%
X, y = titanic_df.loc[:, titanic_df.columns != 'Survived'], titanic_df['Survived']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# I chose the survived feature because I thought I can later create a model that can predict survivabilty by economic status
